# %%
# our libraries
import src.dataread;
import src.model as ce240;

# external libraries
import numpy as np;
import pymap3d as pm;
from mpl_toolkits import mplot3d
# %matplotlib notebook
import matplotlib.pyplot as plt

DATASET = "../mammoth_localization";
REF_J   = 0;

# read in the data from the csvs
sensor_data = src.dataread.get_sensor_list(dataset=DATASET);

# TODO move this to dataread.py
nodes = ce240.get_nodes(); # hardcoded node positions (ECEF)
xn,yn,zn = np.hsplit(nodes,3); # legacy to get the x,y,z vectors
# Out:
# Num good sets: 6942

# %%
# get the time series xls output
output_vector_list = ce240.get_series_out(sensor_data, REF_J);

# %%
    
"""
Plots nodes on a 3D coordinate system.
Anchor nodes are in black.
Mobile node is in green.
"""

fig = plt.figure()
ax = plt.axes(projection='3d')

# XYZ location of quadcopter (node 9)
#x = -2455200.7931187
#y = -4425468.23573119
#z = 3873216.13338933

x, y, z = list(zip(*output_vector_list));
x = np.asarray(x);
y = np.asarray(y);
z = np.asarray(z);


# color gradient
cm = plt.get_cmap("RdYlGn");
grad = [cm(float(i)/(len(x))) for i in range(len(x))];

# Print locations of nodes. Node 9 is in a different color
ax.scatter(xn, yn, zn, c='Black', s=10, depthshade=False);
ax.scatter(x, y, z, s=1, c=grad, depthshade=False); # c='Green',

ax.set_xlim3d(float(-40),float(40))
ax.set_ylim3d(float(-40),float(40))
ax.set_zlim3d(float(-40),float(40))

""""ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')"""


# Placement 0, 0 would be the bottom left, 1, 1 would be the top right.
ax.text2D(0.05, 0.95, "ECEF Coordinates of Anchor and Mobile Nodes", transform=ax.transAxes)

plt.show();
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
print(x)

# %%
print(y)

# %%
print(z)

# %%
min(y)

# %%
min(z)

# %%
min(x)

# %%
min(xn)

# %%
min(yn)

# %%
min(zn)

# %%
min()

# %%
z

# %%
plt.show()
